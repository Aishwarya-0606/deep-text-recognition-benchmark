# %% [markdown]
# <a href="https://colab.research.google.com/github/aish0606/deep-text-recognition-benchmark/blob/master/create_lmdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd "/gdrive/My Drive/Code/LMDBexp"
# Out:
# /gdrive/My Drive/Code/LMDBexp

# %%
# %cp -r /gdrive/My\ Drive/Code/deep-text-recognition-benchmark/validation_data .

# %%
# !pip install fire
# Out:
# ...
#      |████████████████████████████████| 81kB 5.0MB/s
# ...
#   Created wheel for fire: filename=fire-0.3.1-py2.py3-none-any.whl size=111005 sha256=150d67c77916cebf768b584d3f3878da39cdde9d33ab31b66ece4c8de1f49697
#   Stored in directory: /root/.cache/pip/wheels/c1/61/df/768b03527bf006b546dce284eb4249b185669e65afc5fbb2ac
# Successfully built fire
# ...

# %%
# !python3 create_lmdb.py \
--inputPath /gdrive/My\ Drive/Code/LMDBexp/validation_data/data \
--gtFile /gdrive/My\ Drive/Code/LMDBexp/validation_data/data/gt.txt \
--outputPath /gdrive/My\ Drive/Code/LMDBexp/validation_data/output/
# Out:
# Streaming output truncated to the last 5000 lines.
# label is JALAN LAPANGAN TERBANG SUBANG
# \label.encode() is b'JALAN LAPANGAN TERBANG SUBANG'
#
# label is 47200 SUBANG
# \label.encode() is b'47200 SUBANG'
#
# label is SELANGOR
# \label.encode() is b'SELANGOR'
#
# label is D'ROSH SERVPORT
# \label.encode() is b"D'ROSH SERVPORT"
#
# label is CO. REG. NO: 000948487-V
# \label.encode() is b'CO. REG. NO: 000948487-V'
#
# label is GST REG. NO: 000768122880
# \label.encode() is b'GST REG. NO: 000768122880'
#
# label is 18-01-2018 15:44:46
# \label.encode() is b'18-01-2018 15:44:46'
#
# label is CASHIER: 888
# \label.encode() is b'CASHIER: 888'
#
# label is INVOICE NO: 1-916166
# \label.encode() is b'INVOICE NO: 1-916166'
#
# label is ITEM
# \label.encode() is b'ITEM'
#
# label is U\PRICE
# \label.encode() is b'U\\PRICE'
#
# label is QNTY
# \label.encode() is b'QNTY'
#
# label is AMOUNT
# \label.encode() is b'AMOUNT'
#
# label is INFINITI 97 E4MP3
# ...
